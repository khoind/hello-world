# %% [markdown]
# # Forecast results

# %%
# Press Shift + enter to run
# Make sure your computer is connected to the Internte
import requests
r = requests.get('https://raw.githubusercontent.com/{}/{}/master/{}.py'.format('khoind', 'hello-world', 'budget_model_v9')).text
exec(r)

# %%
run_model(folder='division_7', year=2018, size=(10,4))
# Out:
# /Users/khoinguyen/anaconda/envs/bunny/lib/python3.6/site-packages/numpy/lib/financial.py:123: RuntimeWarning: invalid value encountered in double_scalars
#   (1 + rate*when)*(temp - 1)/rate + zer)
# ------------------------------------------------------------------------------------------------------
# ALL PRODUCTS
#
# ### Summary ###
# EOP balance, last month: 233317
# TOI - total: 13060.1
# TOI - monthly_average: 1088.3
# NII - total: 6475.0
# NII - monthly_average: 539.6
# NFI - total: 6585.1
# NFI - monthly_average: 548.8
# Provision - total: 3296
# Provision - monthly average: 275
# Provision as % of TOI: 25.2%
# Disbursement - total: 40519.297383
# Disbursement - monthly average: 3376.608115
# Card spend - total: 40682
# Card spend - monthly average: 3390
# Cards issuance - total: 385942
# Cards issuance - monthly average: 32162
# ### Full Table ###
#                       adb  disbursement            eop  monthly_issued  \
# month
# ...

# %%
total, classes, products, subproducts = all_outputs('division_7', year=2018)
